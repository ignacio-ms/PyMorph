# %%
import tensorflow as tf
import numpy as np
import cv2

import matplotlib.pyplot as plt
import seaborn as sns

from cell_division.nets.transfer_learning import CNN
from util.data.dataset_cell import CellDataset
from util import values as v
from util.misc.colors import bcolors as c
from util.misc import visualizer as vis

from sklearn.metrics import classification_report, confusion_matrix
from cell_division.layers.custom_layers import (
    ExtendedLSEPooling,
    extended_w_cel_loss
)

from cell_division.nets.cam import GradCAM, overlay_heatmap, CAM

# GPU config
from util.gpu.gpu_tf import (
    increase_gpu_memory, 
    set_gpu_allocator
)

increase_gpu_memory()
set_gpu_allocator()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 import cv2
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/__init__.py:42
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/data/__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/data/experimental/__init__.py:95
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      91 @@UNKNOWN_CARDINALITY
#      92 """
#      94 # pylint: disable=unused-import
# ---> 95 from tensorflow.python.data.experimental import service
#      96 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/data/experimental/service/__init__.py:387
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     384   job of ParameterServerStrategy).
#     385 """
# --> 387 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     388 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     389 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py:23
#      21 from tensorflow.python import tf2
#      22 from tensorflow.python.compat import compat
# ---> 23 from tensorflow.python.data.experimental.ops import compression_ops
#      24 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      25 from tensorflow.python.data.experimental.service import _pywrap_utils
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/data/experimental/ops/compression_ops.py:16
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ops for compressing and uncompressing dataset elements."""
# ---> 16 from tensorflow.python.data.util import structure
#      17 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      20 def compress(element):
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/data/util/structure.py:22
#      19 import six
#      20 import wrapt
# ---> 22 from tensorflow.python.data.util import nest
#      23 from tensorflow.python.framework import composite_tensor
#      24 from tensorflow.python.framework import ops
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/data/util/nest.py:36
#      16 """## Functions for working with arbitrarily nested sequences of elements.
#      17
#      18 NOTE(mrry): This fork of the `tensorflow.python.util.nest` module
#    (...)
#      31    arrays.
#      32 """
#      34 import six as _six
# ---> 36 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      37 from tensorflow.python.util import _pywrap_utils
#      38 from tensorflow.python.util import nest
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/framework/sparse_tensor.py:24
#      22 from tensorflow.python import tf2
#      23 from tensorflow.python.framework import composite_tensor
# ---> 24 from tensorflow.python.framework import constant_op
#      25 from tensorflow.python.framework import dtypes
#      26 from tensorflow.python.framework import ops
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:25
#      23 from tensorflow.core.framework import types_pb2
#      24 from tensorflow.python.eager import context
# ---> 25 from tensorflow.python.eager import execute
#      26 from tensorflow.python.framework import dtypes
#      27 from tensorflow.python.framework import op_callbacks
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:23
#      21 from tensorflow.python import pywrap_tfe
#      22 from tensorflow.python.eager import core
# ---> 23 from tensorflow.python.framework import dtypes
#      24 from tensorflow.python.framework import ops
#      25 from tensorflow.python.framework import tensor_shape
#
# File ~/mambaforge/envs/py310ml/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:29
#      26 from tensorflow.python.lib.core import _pywrap_bfloat16
#      27 from tensorflow.python.util.tf_export import tf_export
# ---> 29 _np_bfloat16 = _pywrap_bfloat16.TF_bfloat16_type()
#      32 @tf_export("dtypes.DType", "DType")
#      33 class DType(_dtypes.DType):
#      34   """Represents the type of the elements in a `Tensor`.
#      35
#      36   `DType`'s are used to specify the output data type for operations which
#    (...)
#      46   See `tf.dtypes` for a complete list of `DType`'s defined.
#      47   """
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	() -> handle

# %% [markdown]
# Create and save images with just the nuclei

# %%
# img_dir = v.data_path + 'CellDivision/images/'
# img_out_dir = v.data_path + 'CellDivision/images_nuclei/'
# label_dir = v.data_path + 'CellDivision/data.csv'
# 
# data_generator = CellDataset(
#     img_dir, 
#     label_dir,
#     batch_size=1,
#     resize=(50, 50)
# )
# 
# def format_names(idx):
#     return f'{idx:03}.tif'
# 
# for i, (img, label) in enumerate(data_generator):
#     img = np.uint8(img[0][..., 2] * 255)
#     
#     img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
#     cv2.imwrite(img_out_dir + format_names(i+1), img)

# %% [markdown]
# Training

# %%
img_dir = v.data_path + 'CellDivision/images_nuclei/'
label_train_dir = v.data_path + 'CellDivision/undersampled/train.csv'
label_test_dir = v.data_path + 'CellDivision/undersampled/test.csv'
label_val_dir = v.data_path + 'CellDivision/undersampled/val.csv'

INPUT_SHAPE = (100, 100, 3)
BATCH_SIZE = 32
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 img_dir = v.data_path + 'CellDivision/images_nuclei/'
#       2 label_train_dir = v.data_path + 'CellDivision/undersampled/train.csv'
#       3 label_test_dir = v.data_path + 'CellDivision/undersampled/test.csv'
#
# NameError: name 'v' is not defined

# %%
train_generator = CellDataset(
    img_dir, 
    label_train_dir,
    batch_size=BATCH_SIZE,
    resize=INPUT_SHAPE[:2]
)

val_generator = CellDataset(
    img_dir, 
    label_val_dir,
    batch_size=BATCH_SIZE,
    resize=INPUT_SHAPE[:2]
)

test_generator = CellDataset(
    img_dir, 
    label_test_dir,
    batch_size=BATCH_SIZE,
    resize=INPUT_SHAPE[:2]
)

# %%
model = CNN(
    base=tf.keras.applications.VGG16,
    input_shape=INPUT_SHAPE,
    n_classes=3
)
model.build_top(activation='softmax', b_type='CAM', pooling=ExtendedLSEPooling)
model.compile(
    lr=.001,
    loss=extended_w_cel_loss()
)
model.fit(
    train_generator,
    val_generator,
    epochs=100,
    verbose=2,
    batch_size=BATCH_SIZE
)

model.model.save('../models/cellular_division_models/vgg16_nuclei_under.h5')
# Out:
# Epoch 1/100
# 13/13 [==============================] - ETA: 0s - loss: 2.5565 - auc: 0.8093INFO:tensorflow:Assets written to: ../models/cellular_division_models/vgg16.ckpt/assets
# 13/13 [==============================] - 14s 1s/step - loss: 2.5565 - auc: 0.8093 - val_loss: 1.4141 - val_auc: 0.6638 - lr: 0.0010
# Epoch 2/100
# 13/13 [==============================] - 10s 783ms/step - loss: 1.7013 - auc: 0.8804 - val_loss: 1.3143 - val_auc: 0.7710 - lr: 0.0010
# Epoch 3/100
# 13/13 [==============================] - 10s 763ms/step - loss: 1.4887 - auc: 0.9049 - val_loss: 1.2987 - val_auc: 0.7712 - lr: 0.0010
# Epoch 4/100
# 13/13 [==============================] - ETA: 0s - loss: 1.2282 - auc: 0.9150
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 13/13 [==============================] - 10s 753ms/step - loss: 1.2282 - auc: 0.9150 - val_loss: 1.3539 - val_auc: 0.7444 - lr: 0.0010
# Epoch 5/100
# 13/13 [==============================] - 11s 848ms/step - loss: 0.9861 - auc: 0.9326 - val_loss: 1.2747 - val_auc: 0.7699 - lr: 1.0000e-04
# Epoch 6/100
# 13/13 [==============================] - 10s 805ms/step - loss: 0.9876 - auc: 0.9287 - val_loss: 1.2101 - val_auc: 0.8194 - lr: 1.0000e-04
# Epoch 7/100
# 13/13 [==============================] - ETA: 0s - loss: 1.1218 - auc: 0.9256
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 13/13 [==============================] - 10s 758ms/step - loss: 1.1218 - auc: 0.9256 - val_loss: 1.1606 - val_auc: 0.8563 - lr: 1.0000e-04
# Epoch 8/100
# 13/13 [==============================] - 10s 744ms/step - loss: 1.0088 - auc: 0.9254 - val_loss: 1.1142 - val_auc: 0.8888 - lr: 1.0000e-05
# Epoch 9/100
# 13/13 [==============================] - 10s 743ms/step - loss: 0.8942 - auc: 0.9408 - val_loss: 1.0668 - val_auc: 0.9139 - lr: 1.0000e-05
# Epoch 10/100
# 13/13 [==============================] - ETA: 0s - loss: 0.8200 - auc: 0.9468
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 13/13 [==============================] - 9s 737ms/step - loss: 0.8200 - auc: 0.9468 - val_loss: 1.0185 - val_auc: 0.9309 - lr: 1.0000e-05
# Epoch 11/100
# 13/13 [==============================] - 9s 740ms/step - loss: 0.8661 - auc: 0.9459 - val_loss: 0.9702 - val_auc: 0.9401 - lr: 1.0000e-06
# Epoch 12/100
# 13/13 [==============================] - 9s 730ms/step - loss: 0.9948 - auc: 0.9326 - val_loss: 0.9223 - val_auc: 0.9465 - lr: 1.0000e-06
# Epoch 13/100
# 13/13 [==============================] - ETA: 0s - loss: 1.1050 - auc: 0.9249
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 13/13 [==============================] - 9s 731ms/step - loss: 1.1050 - auc: 0.9249 - val_loss: 0.8755 - val_auc: 0.9510 - lr: 1.0000e-06
# Epoch 14/100
# 13/13 [==============================] - 9s 733ms/step - loss: 1.0334 - auc: 0.9354 - val_loss: 0.8302 - val_auc: 0.9544 - lr: 1.0000e-07
# Epoch 15/100
# 13/13 [==============================] - 10s 749ms/step - loss: 0.9629 - auc: 0.9380 - val_loss: 0.7875 - val_auc: 0.9564 - lr: 1.0000e-07
# Epoch 16/100
# 13/13 [==============================] - ETA: 0s - loss: 0.8955 - auc: 0.9444
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 13/13 [==============================] - 10s 765ms/step - loss: 0.8955 - auc: 0.9444 - val_loss: 0.7482 - val_auc: 0.9570 - lr: 1.0000e-07
# Epoch 17/100
# 13/13 [==============================] - 10s 761ms/step - loss: 0.9719 - auc: 0.9399 - val_loss: 0.7124 - val_auc: 0.9580 - lr: 1.0000e-08
# Epoch 18/100
# 13/13 [==============================] - 10s 797ms/step - loss: 0.7765 - auc: 0.9508 - val_loss: 0.6807 - val_auc: 0.9581 - lr: 1.0000e-08
# Epoch 19/100
# 13/13 [==============================] - ETA: 0s - loss: 0.7300 - auc: 0.9537
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 13/13 [==============================] - 9s 726ms/step - loss: 0.7300 - auc: 0.9537 - val_loss: 0.6529 - val_auc: 0.9579 - lr: 1.0000e-08
# Epoch 20/100
# 13/13 [==============================] - 10s 746ms/step - loss: 0.9809 - auc: 0.9314 - val_loss: 0.6292 - val_auc: 0.9586 - lr: 1.0000e-09
# Epoch 21/100
# 13/13 [==============================] - 10s 758ms/step - loss: 1.0729 - auc: 0.9320 - val_loss: 0.6093 - val_auc: 0.9581 - lr: 1.0000e-09
# Epoch 22/100
# 13/13 [==============================] - ETA: 0s - loss: 1.0369 - auc: 0.9321
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 13/13 [==============================] - 10s 745ms/step - loss: 1.0369 - auc: 0.9321 - val_loss: 0.5933 - val_auc: 0.9580 - lr: 1.0000e-09
# Epoch 23/100
# 13/13 [==============================] - 9s 737ms/step - loss: 0.9625 - auc: 0.9340 - val_loss: 0.5808 - val_auc: 0.9585 - lr: 1.0000e-10
# Epoch 24/100
# 13/13 [==============================] - 9s 737ms/step - loss: 1.0512 - auc: 0.9314 - val_loss: 0.5717 - val_auc: 0.9583 - lr: 1.0000e-10
# Epoch 25/100
# 13/13 [==============================] - ETA: 0s - loss: 1.0673 - auc: 0.9270Restoring model weights from the end of the best epoch: 20.
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# 13/13 [==============================] - 9s 731ms/step - loss: 1.0673 - auc: 0.9270 - val_loss: 0.5658 - val_auc: 0.9582 - lr: 1.0000e-10
# Epoch 25: early stopping

# %%
# model = CNN()
# model.load('../models/cellular_division_models/vgg16_nuclei_under.h5')

# %%
results = model.model.evaluate(test_generator, verbose=1)
# Out:
# 4/4 [==============================] - 3s 852ms/step - loss: 0.6904 - auc: 0.9435

# %%
pred = model.model.predict(test_generator).round().astype(int)

print(
    classification_report(
        test_generator.img_labels, [test_generator.oh2class(p) for p in pred], 
        target_names=test_generator.CLASS_NAMES,
        zero_division=0
    )
)
# Out:
#                     precision    recall  f1-score   support
#
# Prophase/Metaphase       0.89      0.81      0.85        42
# Anaphase/Telophase       0.82      0.86      0.84        42
#         Interphase       0.87      0.91      0.89        43
#
#           accuracy                           0.86       127
#          macro avg       0.86      0.86      0.86       127
#       weighted avg       0.86      0.86      0.86       127

# %%
cf_matrix = confusion_matrix(
    test_generator.img_labels, [test_generator.oh2class(p) for p in pred]
)

plt.figure(figsize=(12, 12))
vis.plot_confusion_matrix(cf_matrix)

# %%
test_generator = CellDataset(
    img_dir, 
    label_test_dir, 
    batch_size=1, 
    resize=INPUT_SHAPE[:2]
)

# %%
img_idx = 25 # 87 # 44 # 40 # 0  # 98  # 25
test_img_tf = test_generator[img_idx][0]
test_img = test_img_tf.numpy().astype(np.float32)
test_img = test_img.reshape(INPUT_SHAPE)
test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)

plt.imshow(test_img, cmap='blues'); plt.axis('off')
plt.show()

# %%
cam = CAM(model.model)
heatmap_pm = cam.compute_heatmap(test_img_tf, class_idx=0, normalize=True)
heatmap_at = cam.compute_heatmap(test_img_tf, class_idx=1, normalize=True)
heatmap_i = cam.compute_heatmap(test_img_tf, class_idx=2, normalize=True)

pred = model.model.predict(test_img_tf)
print(f'Real label: {test_generator.oh2name(test_generator[img_idx][1])}')
print(f'Predicted label: {test_generator.oh2name(pred)}')

plt.figure(figsize=(12, 8))
plt.subplot(1, 3, 1)
plt.imshow(overlay_heatmap(test_img, heatmap_pm, alpha=.7, colormap=cv2.COLORMAP_HSV)); plt.axis('off')
plt.title(f'Prophase-Metaphase: {pred[0][0]:.2f}')

plt.subplot(1, 3, 2)
plt.imshow(overlay_heatmap(test_img, heatmap_at, alpha=.7, colormap=cv2.COLORMAP_HSV)); plt.axis('off')
plt.title(f'Anaphase-Telophase: {pred[0][1]:.2f}')

plt.subplot(1, 3, 3)
plt.imshow(overlay_heatmap(test_img, heatmap_i, alpha=.7, colormap=cv2.COLORMAP_HSV)); plt.axis('off')
plt.title(f'Interphase: {pred[0][2]:.2f}')

plt.tight_layout()
plt.show()
# Out:
# Real label: Interphase
# Predicted label: Interphase

# %%
cam = GradCAM(model.model)
heatmap_pm = cam.compute_heatmap(test_img_tf, class_idx=0)
heatmap_at = cam.compute_heatmap(test_img_tf, class_idx=1)
heatmap_i = cam.compute_heatmap(test_img_tf, class_idx=2)

pred = model.model.predict(test_img_tf)
print(f'Real label: {test_generator.oh2name(test_generator[img_idx][1])}')
print(f'Predicted label: {test_generator.oh2name(pred)}')

plt.figure(figsize=(12, 8))
plt.subplot(1, 3, 1)
plt.imshow(overlay_heatmap(test_img, heatmap_pm, alpha=.7, colormap=cv2.COLORMAP_HSV)); plt.axis('off')
plt.title(f'Prophase-Metaphase: {pred[0][0]:.2f}')

plt.subplot(1, 3, 2)
plt.imshow(overlay_heatmap(test_img, heatmap_at, alpha=.7, colormap=cv2.COLORMAP_HSV)); plt.axis('off')
plt.title(f'Anaphase-Telophase: {pred[0][1]:.2f}')

plt.subplot(1, 3, 3)
plt.imshow(overlay_heatmap(test_img, heatmap_i, alpha=.7, colormap=cv2.COLORMAP_HSV)); plt.axis('off')
plt.title(f'Interphase: {pred[0][2]:.2f}')

plt.tight_layout()
plt.show()
# Out:
# Real label: Interphase
# Predicted label: Interphase

# %% [markdown]
# STATISTICS:
#
# Confidence intervals for the test set

# %%
predictions = model.model.predict(test_generator)
prediction_confidence = np.max(predictions, axis=1)
prediction_labels = np.argmax(predictions, axis=1)
original_labels = test_generator.img_labels.astype(int)

# %%
# Histogram of the confidence of the predictions
plt.figure(figsize=(12, 6))

print(f'{c.OKBLUE}Average confidence:{c.ENDC} {np.mean(prediction_confidence)}')
print(f'{c.OKBLUE}Max confidence:{c.ENDC} {np.max(prediction_confidence)}')
print(f'{c.OKBLUE}Min confidence:{c.ENDC} {np.min(prediction_confidence)}')
print(f'{c.OKBLUE}Percentage of correct predictions:{c.ENDC} {np.mean(prediction_labels == original_labels)}')
print(f'{c.OKBLUE}Percentage of incorrect predictions:{c.ENDC} {np.mean(prediction_labels != original_labels)}')
print(f'{c.OKBLUE}Percentage of correct predictions with confidence >= 0.9:{c.ENDC} {np.mean((prediction_labels == original_labels) & (prediction_confidence >= 0.9))}')


sns.histplot(prediction_confidence, bins=50, kde=True, color='skyblue', edgecolor='black')
plt.title('Histogram of the confidence of the predictions')
plt.xlabel('Confidence')
plt.ylabel('Frequency')
plt.show()
# Out:
# Average confidence: 0.7429758310317993
# Max confidence: 0.9953008890151978
# Min confidence: 0.3581979274749756
# Percentage of correct predictions: 0.84251968503937
# Percentage of incorrect predictions: 0.15748031496062992
# Percentage of correct predictions with confidence >= 0.9: 0.2204724409448819

# %% [markdown]
# Confidence per class

# %%
# Confidence per class with seaborn
confidences = []
for i in range(3):
    idx = original_labels == i
    confidences.append(prediction_confidence[idx])
    
plt.figure(figsize=(12, 6))
plt.boxplot(confidences, tick_labels=test_generator.CLASS_NAMES)
plt.title('Confidence per class')
plt.show()

# %%
# Confidence per class histogram

plt.figure(figsize=(12, 6))
sns.histplot(confidences, bins=50, kde=True, color=['skyblue', 'orange', 'green'])
plt.title('Confidence per class')
plt.xlabel('Confidence')
plt.ylabel('Frequency')
plt.legend(test_generator.CLASS_NAMES)
plt.show()
