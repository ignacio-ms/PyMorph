# %%
import yaml
import h5py
import numpy as np
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
import nibabel as nib
import pandas as pd
from IPython.display import clear_output
from skimage.segmentation import find_boundaries
import importlib

# %%
sys.path.insert(1, "/Users/dvarelat/Documents/MASTER/TFM/methods")
import cardiac_region
importlib.reload(cardiac_region)
import cardiac_region as c

# %%
os.listdir("/Users/dvarelat/Documents/MASTER/TFM/DATA//DAPIdv_ejemplos")
# Out:
# ['20190208_E2_DAPIdv_decon_20200526_193148_seg2D_0.5.nii.gz',
#  '.DS_Store',
#  '20190404_E1_DAPIdv_decon_20200601_081046_seg2D_0.5.nii.gz',
#  '20190401_E1_DAPIdv_decon_20200529_095615_seg2D_0.5.nii.gz']

# %%
division = ["20190401_E1"]

# %%
seg2d = "/Users/dvarelat/Documents/MASTER/TFM/DATA/DAPIdv_ejemplos/20190401_E1_DAPIdv_decon_20200529_095615_seg2D_0.5.nii.gz"

# %%
decon05_nu ="/Users/dvarelat/Documents/MASTER/TFM/DATA/DECON_05/DAPI/20190401_E1_DAPI_decon_0.5.nii.gz"

# %%
linefile = "/Users/dvarelat/Documents/MASTER/TFM/DATA/LINES/line_20190401_E1.nii.gz"

# %%
os.path.isfile(decon05_cc_mem)
# Out:
# True

# %%
nuclei05 = nib.load(decon05_nu).get_fdata()
nuclei05 = nuclei05[:,:,:, 0]
nuclei05.shape
# Out:
# (1024, 1024, 680)

# %%
nucleiDIV = nib.load(seg2d).get_fdata()
nucleiDIV = nucleiDIV[:,:,:, 0]
nucleiDIV.shape
# Out:
# (1024, 1024, 680)

# %% [markdown]
# ### CORTAR CARDIAC REGION

# %%
c.load3D_metadata(seg2d)
# Out:
# {'x_size': 1024,
#  'y_size': 1024,
#  'z_size': 590,
#  'x_res': 0.873604,
#  'y_res': 0.873604,
#  'z_res': 0.99691}

# %%
margenes = c.crop_line(linefile, seg2d, escala2048=False, ma=5)

# %%
cut_seg2d = c.crop_embryo(margenes, seg2d)

# %%
cut_seg2d = cut_seg2d[:,:,:, 0]
cut_seg2d.shape

# %%
find_boundaries(nucleiDIV[:,:,n])
# Out:
# (1024, 1024)

# %%
for t in range(24):
    plt.figure(figsize=(20,20)) 
    n = 20*t
    plots = [nuclei05[:,:,n], nucleiDIV[:,:,n]]
    for i in range(len(plots)):
        plt.subplot(1,len(plots), i+1)
        plt.imshow(plots[i])
    plt.show()
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <module>
#       4 plots = [nuclei05[:,:,n], nucleiDIV[:,:,n]]
#       5 for i in range(len(plots)):
# ----> 6     plt.subplot(1,len(plots), i+1)
#       7     plt.imshow(plots[i])
#       8 plt.show()
#
# File /opt/miniconda3/envs/images/lib/python3.10/site-packages/matplotlib/pyplot.py:1283, in subplot(*args, **kwargs)
#    1280             break
#    1281 else:
#    1282     # we have exhausted the known Axes and none match, make a new one!
# -> 1283     ax = fig.add_subplot(*args, **kwargs)
#    1285 fig.sca(ax)
#    1287 bbox = ax.bbox
#
# File /opt/miniconda3/envs/images/lib/python3.10/site-packages/matplotlib/figure.py:772, in FigureBase.add_subplot(self, *args, **kwargs)
#     769         args = tuple(map(int, str(args[0])))
#     770     projection_class, pkw = self._process_projection_requirements(
# ...

# %%
n= 200
plt.figure(figsize=(20,20)) 
plots = [find_boundaries(nucleiDIV[:,:,n])*100 + nuclei05[:,:,n]]
for i in range(len(plots)):
    plt.subplot(1,len(plots), i+1)
    plt.imshow(plots[i])
